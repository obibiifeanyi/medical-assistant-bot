# %%
import os
from langchain.embeddings import OpenAIEmbeddings
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

     # Load embeddings
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Load FAISS indices - try both with and without _medibot suffix
symptom_index_path = "../indices/faiss_symptom_index"
if os.path.exists("../indices/faiss_symptom_index_medibot"):
    symptom_index_path = "../indices/faiss_symptom_index_medibot"

severity_index_path = "../indices/faiss_severity_index"
if os.path.exists("../indices/faiss_severity_index_medibot"):
    severity_index_path = "../indices/faiss_severity_index_medibot"

faiss_symptom = FAISS.load_local(
    symptom_index_path, embeddings,
    allow_dangerous_deserialization=True
)
faiss_severity = FAISS.load_local(
    severity_index_path, embeddings,
    allow_dangerous_deserialization=True
)

# %%
def test_symptom_combinations(faiss_symptom, faiss_severity, embeddings):
    """Test various symptom combinations against the loaded FAISS indices"""
    
    # Sample symptom combinations to test (based on actual disease_symptoms.csv data)
    test_cases = [
        # Respiratory/Cold-like symptoms
        ["cough", "chest pain", "breathlessness"],
        ["continuous sneezing", "watering from eyes", "throat irritation"],
        
        # Digestive issues
        ["stomach pain", "nausea", "vomiting"],
        ["loss of appetite", "dehydration", "weakness of one body side"],
        
        # Fever/Infection patterns  
        ["high fever", "chills", "fatigue"],
        ["headache", "muscle weakness", "sweating"],
        
        # Skin conditions
        ["itching", "skin rash", "redness of eyes"],
        ["skin rash", "joint pain", "skin peeling"],
        
        # Neurological symptoms
        ["headache", "dizziness", "blurred and distorted vision"],
        ["anxiety", "restlessness", "irritability"],
        
        # Urinary/Kidney issues
        ["burning micturition", "bladder discomfort", "foul smell of urine"],
        
        # Cardiovascular symptoms
        ["chest pain", "fast heart rate", "breathlessness"]
    ]
    
    print("="*60)
    print("TESTING SYMPTOM COMBINATIONS ON LOADED FAISS INDICES")
    print("="*60)
    
    for i, symptoms in enumerate(test_cases, 1):
        print(f"\nTest {i}: {', '.join(symptoms)}")
        
        # Create query string from symptoms
        query_text = ", ".join(symptoms)
        
        try:
            # Search symptom index using LangChain's similarity_search_with_score
            symptom_results = faiss_symptom.similarity_search_with_score(query_text, k=3)
            
            print(f"  Symptom Index Results:")
            for j, (doc, score) in enumerate(symptom_results):
                print(f"    {j+1}. Score: {score:.4f} | Content: {doc.page_content[:100]}...")
                if hasattr(doc, 'metadata') and doc.metadata:
                    print(f"       Metadata: {doc.metadata}")
            
        except Exception as e:
            print(f"  Symptom Index Error: {e}")
        
        try:
            # Search severity index
            severity_results = faiss_severity.similarity_search_with_score(query_text, k=3)
            
            print(f"  Severity Index Results:")
            for j, (doc, score) in enumerate(severity_results):
                print(f"    {j+1}. Score: {score:.4f} | Content: {doc.page_content[:100]}...")
                if hasattr(doc, 'metadata') and doc.metadata:
                    print(f"       Metadata: {doc.metadata}")
                    
        except Exception as e:
            print(f"  Severity Index Error: {e}")
        
        print("-" * 40)

def quick_symptom_search(faiss_index, symptoms, index_name="Index", k=5):
    """Quick search function for individual symptom queries"""
    query_text = ", ".join(symptoms) if isinstance(symptoms, list) else symptoms
    
    try:
        results = faiss_index.similarity_search_with_score(query_text, k=k)
        
        print(f"\n{index_name} Results for: '{query_text}'")
        for i, (doc, score) in enumerate(results):
            print(f"  {i+1}. Score: {score:.4f}")
            print(f"     Content: {doc.page_content}")
            if hasattr(doc, 'metadata') and doc.metadata:
                print(f"     Metadata: {doc.metadata}")
                
        return results
        
    except Exception as e:
        print(f"Error searching {index_name}: {e}")
        return []

def compare_indices(faiss_symptom, faiss_severity, query_symptoms):
    """Compare results between symptom and severity indices for the same query"""
    
    print(f"\n{'='*60}")
    print(f"COMPARING INDICES FOR: {', '.join(query_symptoms)}")
    print(f"{'='*60}")
    
    # Search both indices
    symptom_results = quick_symptom_search(faiss_symptom, query_symptoms, "Symptom Index", k=3)
    severity_results = quick_symptom_search(faiss_severity, query_symptoms, "Severity Index", k=3)
    
    # Simple comparison
    if symptom_results and severity_results:
        print(f"\nComparison:")
        print(f"  Best Symptom Match Score: {symptom_results[0][1]:.4f}")
        print(f"  Best Severity Match Score: {severity_results[0][1]:.4f}")
        
        symptom_content = symptom_results[0][0].page_content
        severity_content = severity_results[0][0].page_content
        
        print(f"  Symptom Index Best: {symptom_content[:80]}...")
        print(f"  Severity Index Best: {severity_content[:80]}...")

def batch_test_individual_symptoms(faiss_symptom, faiss_severity):
    """Test individual symptoms to see how the indices respond"""
    
    individual_symptoms = [
        "fever", "headache", "cough", "nausea", "chest pain",
        "dizziness", "fatigue", "skin rash", "vomiting", "anxiety"
    ]
    
    print(f"\n{'='*60}")
    print("TESTING INDIVIDUAL SYMPTOMS")
    print(f"{'='*60}")
    
    for symptom in individual_symptoms:
        print(f"\nTesting: '{symptom}'")
        
        # Get top result from each index
        try:
            sym_result = faiss_symptom.similarity_search_with_score(symptom, k=1)[0]
            sev_result = faiss_severity.similarity_search_with_score(symptom, k=1)[0]
            
            print(f"  Symptom: {sym_result[1]:.4f} | {sym_result[0].page_content[:50]}...")
            print(f"  Severity: {sev_result[1]:.4f} | {sev_result[0].page_content[:50]}...")
            
        except Exception as e:
            print(f"  Error: {e}")

# Main execution function
def run_all_tests(faiss_symptom, faiss_severity, embeddings):
    """Run all tests using your loaded FAISS indices"""
    
    print("Starting comprehensive symptom testing...")
    print(f"Symptom Index: {faiss_symptom}")
    print(f"Severity Index: {faiss_severity}")
    
    # Run the main symptom combination tests
    test_symptom_combinations(faiss_symptom, faiss_severity, embeddings)
    
    # Test individual symptoms
    batch_test_individual_symptoms(faiss_symptom, faiss_severity)
    
    # Example comparison
    compare_indices(faiss_symptom, faiss_severity, ["fever", "headache", "fatigue"])
    
    print(f"\n{'='*60}")
    print("ALL TESTS COMPLETED")
    print(f"{'='*60}")

# Usage:
# Assuming you have already loaded your indices as shown in your code:
run_all_tests(faiss_symptom, faiss_severity, embeddings)
# Out:
# Starting comprehensive symptom testing...
# Symptom Index: <langchain_community.vectorstores.faiss.FAISS object at 0x00000194A95E2950>
# Severity Index: <langchain_community.vectorstores.faiss.FAISS object at 0x00000194A9F2B650>
# ============================================================
# TESTING SYMPTOM COMBINATIONS ON LOADED FAISS INDICES
# ============================================================
#
# Test 1: cough, chest pain, breathlessness
#   Symptom Index Results:
#     1. Score: 0.2225 | Content: vomiting, breathlessness, chest pain...
#        Metadata: {'disease': 'heart attack'}
#     2. Score: 0.3563 | Content: breathlessness, sweating, chest pain...
#        Metadata: {'disease': 'heart attack'}
#     3. Score: 0.4396 | Content: vomiting, breathlessness, sweating, chest pain...
#        Metadata: {'disease': 'heart attack'}
#   Severity Index Results:
#     1. Score: 0.5518 | Content: chest pain...
#     2. Score: 0.6531 | Content: breathlessness...
#     3. Score: 1.1602 | Content: stomach pain...
# ----------------------------------------
#
# Test 2: continuous sneezing, watering from eyes, throat irritation
#   Symptom Index Results:
#     1. Score: 0.2448 | Content: continuous sneezing, chills, watering from eyes...
#        Metadata: {'disease': 'allergy'}
#     2. Score: 0.2987 | Content: continuous sneezing, shivering, watering from eyes...
#        Metadata: {'disease': 'allergy'}
#     3. Score: 0.3784 | Content: continuous sneezing, shivering, chills, watering from eyes...
#        Metadata: {'disease': 'allergy'}
#   Severity Index Results:
#     1. Score: 0.5692 | Content: continuous sneezing...
#     2. Score: 0.7778 | Content: throat irritation...
#     3. Score: 0.7800 | Content: watering from eyes...
# ----------------------------------------
#
# Test 3: stomach pain, nausea, vomiting
#   Symptom Index Results:
#     1. Score: 0.3959 | Content: stomach pain, acidity, vomiting, cough, chest pain...
#        Metadata: {'disease': 'gerd'}
#     2. Score: 0.4139 | Content: vomiting, indigestion, loss of appetite, abdominal pain, internal itching...
#        Metadata: {'disease': 'peptic ulcer diseae'}
#     3. Score: 0.4713 | Content: vomiting, indigestion, loss of appetite, abdominal pain, passage of gases...
#        Metadata: {'disease': 'peptic ulcer diseae'}
#   Severity Index Results:
#     1. Score: 0.5403 | Content: nausea...
#     2. Score: 0.5407 | Content: stomach pain...
#     3. Score: 0.6727 | Content: vomiting...
# ----------------------------------------
#
# Test 4: loss of appetite, dehydration, weakness of one body side
#   Symptom Index Results:
#     1. Score: 0.4789 | Content: vomiting, headache, weakness of one body side...
#        Metadata: {'disease': 'paralysis (brain hemorrhage)'}
#     2. Score: 0.7280 | Content: vomiting, headache, weakness of one body side, altered sensorium...
#        Metadata: {'disease': 'paralysis (brain hemorrhage)'}
#     3. Score: 0.7424 | Content: vomiting, weakness of one body side, altered sensorium...
#        Metadata: {'disease': 'paralysis (brain hemorrhage)'}
#   Severity Index Results:
#     1. Score: 0.5416 | Content: weakness of one body side...
#     2. Score: 0.6047 | Content: loss of appetite...
#     3. Score: 0.8646 | Content: increased appetite...
# ----------------------------------------
#
# Test 5: high fever, chills, fatigue
#   Symptom Index Results:
#     1. Score: 0.3890 | Content: chills, vomiting, high fever, sweating, headache, nausea, muscle pain...
#        Metadata: {'disease': 'malaria'}
#     2. Score: 0.4504 | Content: chills, high fever, sweating, headache, nausea, diarrhoea, muscle pain...
#        Metadata: {'disease': 'malaria'}
#     3. Score: 0.4510 | Content: chills, vomiting, high fever, sweating, headache, diarrhoea, muscle pain...
#        Metadata: {'disease': 'malaria'}
#   Severity Index Results:
#     1. Score: 0.5160 | Content: high fever...
#     2. Score: 0.7175 | Content: mild fever...
#     3. Score: 0.9452 | Content: shivering...
# ----------------------------------------
#
# Test 6: headache, muscle weakness, sweating
#   Symptom Index Results:
#     1. Score: 0.6222 | Content: headache, chest pain, dizziness, lack of concentration...
#        Metadata: {'disease': 'hypertension'}
#     2. Score: 0.6299 | Content: headache, chest pain, loss of balance, lack of concentration...
#        Metadata: {'disease': 'hypertension'}
#     3. Score: 0.6361 | Content: headache, dizziness, loss of balance, lack of concentration...
#        Metadata: {'disease': 'hypertension'}
#   Severity Index Results:
#     1. Score: 0.7737 | Content: headache...
#     2. Score: 0.8244 | Content: muscle weakness...
#     3. Score: 0.9109 | Content: sweating...
# ----------------------------------------
#
# Test 7: itching, skin rash, redness of eyes
#   Symptom Index Results:
#     1. Score: 0.3299 | Content: itching, vomiting, yellowish skin, nausea, loss of appetite, yellowing of eyes...
#        Metadata: {'disease': 'chronic cholestasis'}
#     2. Score: 0.3550 | Content: itching, vomiting, yellowish skin, nausea, abdominal pain, yellowing of eyes...
#        Metadata: {'disease': 'chronic cholestasis'}
#     3. Score: 0.4077 | Content: itching, vomiting, yellowish skin, nausea, loss of appetite, abdominal pain, yellowing of eyes...
#        Metadata: {'disease': 'chronic cholestasis'}
#   Severity Index Results:
#     1. Score: 0.7184 | Content: redness of eyes...
#     2. Score: 0.7272 | Content: skin rash...
#     3. Score: 0.8344 | Content: yellowing of eyes...
# ----------------------------------------
#
# Test 8: skin rash, joint pain, skin peeling
#   Symptom Index Results:
#     1. Score: 0.2946 | Content: skin rash, joint pain, skin peeling, silver like dusting, inflammatory nails...
#        Metadata: {'disease': 'psoriasis'}
#     2. Score: 0.3513 | Content: skin rash, joint pain, skin peeling, small dents in nails, inflammatory nails...
#        Metadata: {'disease': 'psoriasis'}
#     3. Score: 0.4131 | Content: skin rash, joint pain, skin peeling, silver like dusting, small dents in nails, inflammatory nails...
#        Metadata: {'disease': 'psoriasis'}
#   Severity Index Results:
#     1. Score: 0.5408 | Content: skin rash...
#     2. Score: 0.6314 | Content: skin peeling...
#     3. Score: 1.0191 | Content: nodal skin eruptions...
# ----------------------------------------
#
# Test 9: headache, dizziness, blurred and distorted vision
#   Symptom Index Results:
#     1. Score: 0.4534 | Content: headache, dizziness, loss of balance, lack of concentration...
#        Metadata: {'disease': 'hypertension'}
#     2. Score: 0.5095 | Content: headache, chest pain, dizziness, lack of concentration...
#        Metadata: {'disease': 'hypertension'}
#     3. Score: 0.5587 | Content: headache, chest pain, dizziness, loss of balance...
#        Metadata: {'disease': 'hypertension'}
#   Severity Index Results:
#     1. Score: 0.5353 | Content: blurred and distorted vision...
#     2. Score: 0.6027 | Content: dizziness...
#     3. Score: 0.8122 | Content: headache...
# ----------------------------------------
#
# Test 10: anxiety, restlessness, irritability
#   Symptom Index Results:
#     1. Score: 0.6898 | Content: fatigue, mood swings, restlessness, sweating, diarrhoea, fast heart rate, excessive hunger, muscle w...
#        Metadata: {'disease': 'hyperthyroidism'}
#     2. Score: 0.7114 | Content: fatigue, mood swings, weight loss, restlessness, diarrhoea, fast heart rate, excessive hunger, muscl...
#        Metadata: {'disease': 'hyperthyroidism'}
#     3. Score: 0.7159 | Content: vomiting, fatigue, anxiety, sweating, headache, nausea, blurred and distorted vision, excessive hung...
#        Metadata: {'disease': 'hypoglycemia'}
#   Severity Index Results:
#     1. Score: 0.4522 | Content: restlessness...
#     2. Score: 0.6972 | Content: anxiety...
#     3. Score: 0.7568 | Content: irritability...
# ----------------------------------------
#
# Test 11: burning micturition, bladder discomfort, foul smell of urine
#   Symptom Index Results:
#     1. Score: 0.0000 | Content: burning micturition, bladder discomfort, foul smell of urine...
#        Metadata: {'disease': 'urinary tract infection'}
#     2. Score: 0.0596 | Content: burning micturition, bladder discomfort, foul smell of urine, continuous feel of urine...
#        Metadata: {'disease': 'urinary tract infection'}
#     3. Score: 0.1504 | Content: burning micturition, foul smell of urine, continuous feel of urine...
#        Metadata: {'disease': 'urinary tract infection'}
#   Severity Index Results:
#     1. Score: 0.6304 | Content: bladder discomfort...
#     2. Score: 0.9289 | Content: burning micturition...
#     3. Score: 0.9552 | Content: yellow urine...
# ----------------------------------------
#
# Test 12: chest pain, fast heart rate, breathlessness
#   Symptom Index Results:
#     1. Score: 0.4393 | Content: vomiting, breathlessness, chest pain...
#        Metadata: {'disease': 'heart attack'}
#     2. Score: 0.4474 | Content: breathlessness, sweating, chest pain...
#        Metadata: {'disease': 'heart attack'}
#     3. Score: 0.5232 | Content: chest pain, dizziness, loss of balance, lack of concentration...
#        Metadata: {'disease': 'hypertension'}
#   Severity Index Results:
#     1. Score: 0.5506 | Content: chest pain...
#     2. Score: 0.7144 | Content: breathlessness...
#     3. Score: 1.0335 | Content: fast heart rate...
# ----------------------------------------
#
# ============================================================
# TESTING INDIVIDUAL SYMPTOMS
# ============================================================
#
# Testing: 'fever'
#   Symptom: 0.8661 | high fever, blister, red sore around nose, yellow ...
#   Severity: 0.3433 | high fever...
#
# Testing: 'headache'
#   Symptom: 0.8167 | headache, weakness of one body side, altered senso...
#   Severity: 0.0000 | headache...
#
# Testing: 'cough'
#   Symptom: 1.3425 | cough, high fever, breathlessness, family history,...
#   Severity: 0.0000 | cough...
#
# Testing: 'nausea'
#   Symptom: 0.7599 | vomiting, nausea, spinning movements, loss of bala...
#   Severity: 0.0000 | nausea...
#
# Testing: 'chest pain'
#   Symptom: 0.6548 | chest pain, dizziness, loss of balance, lack of co...
#   Severity: 0.0000 | chest pain...
#
# Testing: 'dizziness'
#   Symptom: 0.6508 | headache, dizziness, loss of balance, lack of conc...
#   Severity: 0.0000 | dizziness...
#
# Testing: 'fatigue'
#   Symptom: 1.0552 | fatigue, yellowish skin, nausea, yellowing of eyes...
#   Severity: 0.0000 | fatigue...
#
# Testing: 'skin rash'
#   Symptom: 0.5113 | itching, skin rash, nodal skin eruptions...
#   Severity: 0.0000 | skin rash...
#
# Testing: 'vomiting'
#   Symptom: 0.6124 | vomiting, dehydration, diarrhoea...
#   Severity: 0.0000 | vomiting...
#
# Testing: 'anxiety'
#   Symptom: 1.1598 | shivering, chills, watering from eyes...
#   Severity: 0.0000 | anxiety...
#
# ============================================================
# COMPARING INDICES FOR: fever, headache, fatigue
# ============================================================
#
# Symptom Index Results for: 'fever, headache, fatigue'
#   1. Score: 0.5063
#      Content: chills, vomiting, high fever, sweating, headache, nausea, muscle pain
#      Metadata: {'disease': 'malaria'}
#   2. Score: 0.5603
#      Content: chills, vomiting, high fever, sweating, headache, diarrhoea, muscle pain
#      Metadata: {'disease': 'malaria'}
#   3. Score: 0.5690
#      Content: skin rash, fatigue, lethargy, high fever, headache, loss of appetite, mild fever, swelled lymph nodes, malaise, red spots over body
#      Metadata: {'disease': 'chicken pox'}
#
# Severity Index Results for: 'fever, headache, fatigue'
#   1. Score: 0.7359
#      Content: high fever
#   2. Score: 0.7439
#      Content: mild fever
#   3. Score: 0.9285
#      Content: headache
#
# Comparison:
#   Best Symptom Match Score: 0.5063
#   Best Severity Match Score: 0.7359
#   Symptom Index Best: chills, vomiting, high fever, sweating, headache, nausea, muscle pain...
#   Severity Index Best: high fever...
#
# ============================================================
# ALL TESTS COMPLETED
# ============================================================
